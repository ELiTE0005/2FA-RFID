# %% [markdown]
# <a href="https://colab.research.google.com/github/ELiTE0005/2FA-RFID/blob/main/EXP_15_YOLO_object_detection_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Implement YOLO object detection on an image or video.

# %% [markdown]
# ## Install dependencies
#
# ### Subtask:
# Install necessary libraries for YOLO object detection.

# %% [markdown]
# **Reasoning**:
# The first step is to install the `ultralytics` library using pip, as specified in the instructions.

# %%
# %pip install ultralytics

# %% [markdown]
# ## Load yolo model
#
# ### Subtask:
# Load a pre-trained YOLO model for object detection.

# %% [markdown]
# **Reasoning**:
# Import the YOLO class and load a pre-trained model.

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8n model
model = YOLO('yolov8n.pt')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4040805281.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # Load a pre-trained YOLOv8n model
#       4 model = YOLO('yolov8n.pt')
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Reasoning**:
# The previous command failed because the `ultralytics` library was not found. Although it was installed in a previous step, the kernel might have restarted or the installation was not effective in the current environment. Re-installing the library in the current environment should resolve the issue.

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Reasoning**:
# The re-installation of `ultralytics` was successful. Now, attempt to import the `YOLO` class and load the pre-trained model again as per the original instructions.

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8n model
model = YOLO('yolov8n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %% [markdown]
# ## Load and preprocess image/video
#
# ### Subtask:
# Load the image or video you want to perform object detection on and preprocess it for the YOLO model.

# %% [markdown]
# **Reasoning**:
# Since no image or video file is provided, I will define a variable to hold the path to a placeholder image file that can be used for demonstration purposes. This fulfills the requirement of having a file path ready for the YOLO model.

# %%
# Define the path to a placeholder image file
# Replace 'path/to/your/image_or_video.jpg' with the actual path to your file
# For demonstration, we'll use a placeholder string.
image_or_video_path = 'path/to/your/image_or_video.jpg'

# If you were using a video, you would load it here using OpenCV, for example:
# import cv2
# cap = cv2.VideoCapture(image_or_video_path)

# %% [markdown]
# ## Perform object detection
#
# ### Subtask:
# Apply the YOLO model to the preprocessed image or video to detect objects.

# %% [markdown]
# **Reasoning**:
# Call the `predict` method on the loaded YOLO model with the image or video path and store the results.

# %%
# Apply the YOLO model to the preprocessed image or video
results = model.predict(image_or_video_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3022177157.py in <cell line: 0>()
#       1 # Apply the YOLO model to the preprocessed image or video
# ----> 2 results = model.predict(image_or_video_path)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     538         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     539             self.predictor.set_prompts(prompts)
# --> 540         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     541
#     542     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the placeholder image path does not exist. Since the goal is to demonstrate applying the model, I will use one of the files in the kernel as the input to the model.

# %%
# Use a file from the kernel as the input source
image_or_video_path = '/content/yolov8n.pt'

# Apply the YOLO model to the specified file
results = model.predict(image_or_video_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1566303666.py in <cell line: 0>()
#       3
#       4 # Apply the YOLO model to the specified file
# ----> 5 results = model.predict(image_or_video_path)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     538         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     539             self.predictor.set_prompts(prompts)
# --> 540         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     541
#     542     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
# ...

# %% [markdown]
# ## Perform object detection
#
# ### Subtask:
# Apply the YOLO model to the preprocessed image or video to detect objects.

# %% [markdown]
# **Reasoning**:
# Apply the YOLO model to a sample image that comes with the ultralytics library to detect objects.

# %%
# Apply the YOLO model to a sample image that comes with ultralytics
results = model.predict('bus.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2575324151.py in <cell line: 0>()
#       1 # Apply the YOLO model to a sample image that comes with ultralytics
# ----> 2 results = model.predict('bus.jpg')
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     538         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     539             self.predictor.set_prompts(prompts)
# --> 540         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     541
#     542     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the sample image 'bus.jpg' was not found. I need to use the full path to the sample image provided by ultralytics to ensure it is located correctly.

# %%
import os
from ultralytics.utils import ASSETS

# Apply the YOLO model to a sample image provided by ultralytics
sample_image_path = os.path.join(ASSETS, 'bus.jpg')
results = model.predict(sample_image_path)
# Out:
# image 1/1 /usr/local/lib/python3.12/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 354.1ms
# Speed: 30.9ms preprocess, 354.1ms inference, 31.4ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# ## Visualize results
#
# ### Subtask:
# Draw bounding boxes and labels on the image/video to visualize the detected objects.

# %% [markdown]
# **Reasoning**:
# Access the visualization data from the `results` object and use its `plot()` method to draw bounding boxes and labels on the image, then display the resulting image.

# %%
# Access the visualization data and plot the results
results_image = results[0].plot()

# Display the image with visualizations
# If in a Colab environment, you can use cv2_imshow
# If using matplotlib, you'd typically convert the image format if needed and display
# For simplicity, assuming a common image format returned by plot()
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 12))
plt.imshow(results_image)
plt.axis('off') # Hide axes
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `ultralytics` library was successfully installed, providing the necessary tools for YOLO object detection.
# *   A pre-trained YOLOv8n model (`yolov8n.pt`) was successfully loaded for object detection.
# *   The `ultralytics` YOLO implementation handles image and video preprocessing internally, only requiring the file path as input.
# *   Attempting to use an invalid file path or a file that is not a supported image/video format for prediction results in a `FileNotFoundError`.
# *   Using the correct path to a sample image provided by the `ultralytics` library (`bus.jpg`) successfully allowed the model to perform object detection, identifying objects such as persons, a bus, and a stop sign.
# *   The `plot()` method of the detection results object successfully generated an image with bounding boxes and labels drawn around the detected objects.
#
# ### Insights or Next Steps
#
# *   The `ultralytics` library simplifies the object detection workflow by handling preprocessing and providing built-in visualization tools.
# *   Future steps could involve applying the trained model to a custom dataset of images or videos and evaluating its performance.
